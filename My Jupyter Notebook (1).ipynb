# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SRISHTI NAUTIYAL**
# Data Scientist

# %% [markdown]
# *I want to be a data scientist because I think data is the future, it will be used everywhere, making intrepretation from unorganised data, using different tools, vizualising data will help companies to improve and making better products*

# %% [markdown]
# simple addition

# %%
22+32
# Out:
# 54

# %% [markdown]
# ---
#  -
# 1.
# 2.
# 3.
#
# [Article on what types of bonds deliver the best return](https://www.livemint.com/mutual-fund/mf-news/what-types-of-bonds-deliver-the-best-returns-11670415399535.html)
#
# ~~strikethrough~~
#
# >this is block quotes
# >>Second line of block quotes
# >>>third line
